# %%
a = []
for i in range (1,3):
    n = int(input())
    a.append(n)
print(max(a))
# Out:
# 32

# %%
a = []
for i in range (1,3):
    n = int(input())
    a.append(n)
b = list(a[::-1])
print(b)
# Out:
# [321, 123]

# %%
def prime(n):
    for i in range (2,n):
        if n % i == 0:
            break
        return False
    return True

# %%
def perfect(n):
    a = []
    tong_uoc = 0
    for i in range (2,n):
        if n % i == 0:
            a.append(i)
            for x in a
                tong_uoc += i
    if tong_uoc == n:
        return True
    return False

# %%
n = list(map(int, input().split()))
k =  int(input())
for x in n:
    if k == x:
        print(n.index(x))
        if x == n[-1] and k != n[-1]:
            print(-1)

# %%
a = []
n = int(input("nhap vao so gia tri ban muon nhap"))
for i in range (1,n+1):
    b = int(input())
    a.append(b)
for x in a:
    if x >= 0:
        x = b
        a.remove(x)
        a.insert(0,b)
        print(a)
# Out:
# [2, -1]

# %%
n = input("nhap vao phep toan can thuc hien")
a = float(input("nhap vao num 1"))
b = float(input("nhap vao num 2"))
if n =='+':
    print(round(a+b,2))
elif n =='*':
    print(round(a*b,2))
elif n =='/':
    print(round(a/b, 2))
elif n=='-':
    print(round(a-b,2))
# Out:
# 3.0

# %%
n = int(input())
a = []
m = 0
while n/10 >= 0.1:
    c = n % 10
    a.append(c)
    n = n//10
for x in a:
    m += x
print(m)
# Out:
# 6

# %%
def binary(n):
    a = []
    while n >0:
        c = n % 2
        a.append(c)
        n = n // 2
    return a[::-1]
a,b=map(int,input().split())
c = 0
x = 0
y = 0
A,B=binary(a),binary(b)
if len(A) < len(B):
    for _ in range (len(B)-len(A)):
        A.insert(0, 0)
    for j in range (0, len(B)):
        if A[j] != B[j]:
            x = x + 1
    print(x)
if len(A) > len(B):
    for _ in range (len(A)-len(B)):
        B.insert(0, 0)
    for j in range (0, len(A)):
        if B[j] != A[j]:
            y = y + 1
    print(y)
# Out:
# 7

# %%
n = int(input("nhap vao so ky tu ban cua day A:"))
A = []
B = []
C = []
c = 0
for i in range (1, n+1):
    N = str(input("nhap vao cac ky tu cua day A"))
    A.append(N)
A = C
m = int(input("nhap vao so cac ky tu cua day b"))
for i in range (1, m+1):
    M = str(input("nhap vao cac ky tu cua day b"))
    B = B.append(M)
if len(A) != len(B):
    print("khong dang cau")
else:
    for j in range(0, len(a)):
        if A[j] != B[j]:
            A.pop(j)
            A.append(B[j])
            c = c + 1
            print(A)
    if c == len(set(C)):
        print("dang cau")
    else:
        print("khong dang cau")
print(c)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 8
#       6 for i in range (1, n+1):
#       7     N = str(input("nhap vao cac ky tu cua day A"))
# ----> 8     A = A.append(N)
#       9 A = C
#      10 m = int(input("nhap vao so cac ky tu cua day b"))
#
# AttributeError: 'NoneType' object has no attribute 'append'

# %%
def binary(n):
    res=''
    while n > 0:
        res=str(n%2)+res
        n=n//2
    return res
a,b=map(int,input().split())
a,b=binary(a),binary(b)
if len(a)>len(b):
    a,b=b,a
sum=0
for i in range (len(a)):
    if a[i] != b[i]:
        sum+=1
sum+=len(b)-len(a)
print(sum)
# Out:
# 9
